# %% [markdown]
# ### Setup
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/pyproject.toml) and check software and hardware.
#
# [![PyPI - Version](https://img.shields.io/pypi/v/ultralytics?logo=pypi&logoColor=white)](https://pypi.org/project/ultralytics/) [![Downloads](https://static.pepy.tech/badge/ultralytics)](https://www.pepy.tech/projects/ultralytics) [![PyPI - Python Version](https://img.shields.io/pypi/pyversions/ultralytics?logo=python&logoColor=gold)](https://pypi.org/project/ultralytics/)

# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

# %%
import ultralytics
import cv2 as cv
import numpy as np
from ultralytics import solutions
from datetime import datetime

from utils import get_coordinates, crop_and_mask_image, stack_image

ultralytics.checks()
# Out:
# Ultralytics 8.3.74  Python-3.10.11 torch-2.6.0+cpu CPU (11th Gen Intel Core(TM) i7-11700 2.50GHz)
# Setup complete  (20 CPUs, 31.8 GB RAM, 365.5/476.1 GB disk)
# Setup complete  (20 CPUs, 31.8 GB RAM, 365.5/476.1 GB disk)

# %% [markdown]
# ### Read the Video File and Write the Output to AVI
#
# - You can either read the video file directly or stream the content from an RTSP (Real-Time Streaming Protocol) source, allowing for flexible video input depending on your needs.
# - We will also set up the video writer to handle the output video writing.

# %%
name_model = "yolo11n_100_best"
# name_model = "yolo11m"
name_video = "alpha.mp4"
name_datetime = str(datetime.now().replace(microsecond=0)).replace("-", "").replace(":", "").replace(" ", "_")
name_result = f'{name_model}_{name_video.split(".")[0]}_{name_datetime}'

cap = cv.VideoCapture(f"../../asset/{name_video}")
assert cap.isOpened(), "Error reading video file"
w, h, fps = (
    int(cap.get(x)) 
    for x in (cv.CAP_PROP_FRAME_WIDTH, cv.CAP_PROP_FRAME_HEIGHT, cv.CAP_PROP_FPS)
)

# Video writer
video_writer = cv.VideoWriter(f"../../asset/result/{name_result}.avi", cv.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# %% [markdown]
# ### Define Region Coordinates
#
# Here, we set the coordinates for specific regions to ensure accurate object tracking and analysis within the video or stream. This helps monitor and count objects effectively in different areas.

# %%
success, imx = cap.read()

# # alpha.mp4
# region_points = [(780, 225), (1136, 622)]  # original
region_points = [(120, 30), (400, 475)]   # crop
x_min, x_max = 705, 1456
y_min, y_max = 132, 665
imx_crop = imx[y_min:y_max, x_min:x_max]
polygon = np.array([(0, 0), (388, 531), (750, 189), (304, 1)])

# # delta.mp4
# region_points = [(233, 800), (1795, 800)]  # original
# region_points = [(0, 250), (1178, 250)]    # crop
# x_min, x_max = 422, 1600
# y_min, y_max = 140, 510
# imx_crop = imx[y_min:y_max, x_min:x_max]
# polygon = np.array([(0, imx_crop.shape[0]), (273, 0), (950, 0), (imx_crop.shape[1], imx_crop.shape[0])])

# # beta.mp4
# region_points = [(275, 250), (580, 250)]  # original
# region_points = [(25, 130), (330, 130)]   # crop
# x_min, x_max = 250, 600
# y_min, y_max = 120, 290
# imx_crop = imx[y_min:y_max, x_min:x_max]
# polygon = np.array([(0, imx_crop.shape[0]), (130, 0), (245, 0), (imx_crop.shape[1], imx_crop.shape[0])])

# region_points = [(20, 400), (1080, 400), (1080, 360), (20, 360)]  # For rectangle region counting
# region_points = [(20, 400), (1080, 400), (1080, 360), (20, 360), (20, 400)]  # For polygon region counting

# %% [markdown]
# Original Image

# %%
success, imx = cap.read()

# Buat window dan set event callback
cv.namedWindow("Image", cv.WINDOW_NORMAL)
cv.namedWindow("Image")
cv.setMouseCallback("Image", get_coordinates)
cv.imshow("Image", imx)
cv.waitKey(0)
# Out:
# Mouse Hovering at: (737, 242)
# Mouse Hovering at: (1301, 467)
# -1

# %% [markdown]
# Crop Image

# %%
# success, imx = cap.read()

# imx_crop = imx[y_min:y_max, x_min:x_max]
# imx_crop = crop_and_mask_image(imx, x_min, x_max, y_min, y_max, polygon)
# print(imx_crop.shape)

# cv.namedWindow("Image", cv.WINDOW_NORMAL)
# cv.namedWindow("Image")
# cv.setMouseCallback("Image", get_coordinates)
# cv.imshow("Image", imx_crop)
# cv.waitKey(0)
# Out:
# (700, 750, 3)
# Mouse Hovering at: (154, 130)
# Mouse Hovering at: (452, 415)
# Mouse Hovering at: (122, 32)
# Mouse Hovering at: (406, 476)
# -1

# %% [markdown]
# ### Initialize the ObjectCounter Class
#
# - Now, let's initialize the `ObjectCounter` class to track and count objects in each frame of the video.

# %%
# model = YOLO("yolo11m.pt")
# path = model.export(format="onnx")

# %%
# Init ObjectCounter
counter = solutions.ObjectCounter(
    region=region_points,                           # Pass region points
    model=f"../../asset/result/{name_model}.pt",    # model="yolo11n-obb.pt" for object counting using YOLO11 OBB model.
    # classes=[1, 2, 3, 5, 6, 7, 8, 17, ],            # If you want to count specific classes i.e person and car with COCO pretrained model.
    show=True,                                      # Display the output
    show_in=True,                                   # Display in counts
    show_out=True,                                  # Display out counts
    line_width=1,                                   # Adjust the line width for bounding boxes and text display
    # font_size=0.1,
)
# Out:
# Ultralytics Solutions:  {'region': [(25, 130), (330, 130)], 'show_in': True, 'show_out': True, 'colormap': None, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'json_file': None, 'records': 5, 'show': True, 'model': '../../asset/result/yolo11n_100_best.pt', 'classes': [1, 2, 3, 5, 6, 7, 8, 17], 'line_width': 1, 'font_size': 0.1}

# %% [markdown]
# ### Process Video Frames
#
# In this step, we will process each frame of the video to detect and analyze objects. This allows for real-time tracking and counting, based on the visual data in the frames.

# %%
i = 0
n_skip = 1
is_skip = True

cv.namedWindow("Ultralytics Solutions", cv.WINDOW_NORMAL)
while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    
    if i == n_skip and is_skip:
        i = 0
        continue
    
    im0_original = im0.copy()
    im0 = crop_and_mask_image(im0, x_min, x_max, y_min, y_max, polygon)
    im0 = counter.count(im0)
    print(f"Classwise counts: {counter.classwise_counts}")
    print(f"Counted IDs: {counter.counted_ids}")
    
    im0 = stack_image(im0_original, im0, x_min, x_max, y_min, y_max)
    counter.display_counts(im0)
    video_writer.write(im0)
    
    i += 1

cap.release()   # Release the capture
video_writer.release()
cv.destroyAllWindows()
# Out:
# 0: 320x640 5 motorbikes, 2 cars, 1 person, 40.6ms
# Speed: 1.3ms preprocess, 40.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 2 cars, 35.7ms
# Speed: 1.5ms preprocess, 35.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 2 cars, 32.9ms
# Speed: 1.0ms preprocess, 32.9ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 2 cars, 35.0ms
# Speed: 1.0ms preprocess, 35.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 2 cars, 35.9ms
# Speed: 1.0ms preprocess, 35.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 46.4ms
# Speed: 0.0ms preprocess, 46.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 2 cars, 42.0ms
# Speed: 0.0ms preprocess, 42.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 37.0ms
# Speed: 1.0ms preprocess, 37.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 36.5ms
# Speed: 0.0ms preprocess, 36.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 31.7ms
# Speed: 1.5ms preprocess, 31.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 2 cars, 36.7ms
# Speed: 1.0ms preprocess, 36.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 37.7ms
# Speed: 0.0ms preprocess, 37.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 35.9ms
# Speed: 0.0ms preprocess, 35.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 55.5ms
# Speed: 0.0ms preprocess, 55.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 38.1ms
# Speed: 2.2ms preprocess, 38.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 37.9ms
# Speed: 1.5ms preprocess, 37.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 35.5ms
# Speed: 0.0ms preprocess, 35.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 42.3ms
# Speed: 5.8ms preprocess, 42.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 34.1ms
# Speed: 0.8ms preprocess, 34.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 34.1ms
# Speed: 2.1ms preprocess, 34.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 33.2ms
# Speed: 2.0ms preprocess, 33.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 33.0ms
# Speed: 1.2ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 34.0ms
# Speed: 0.0ms preprocess, 34.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 43.8ms
# Speed: 0.0ms preprocess, 43.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 46.0ms
# Speed: 1.0ms preprocess, 46.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 33.8ms
# Speed: 0.0ms preprocess, 33.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 31.9ms
# Speed: 4.1ms preprocess, 31.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 32.0ms
# Speed: 4.6ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 34.2ms
# Speed: 0.0ms preprocess, 34.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 33.4ms
# Speed: 0.7ms preprocess, 33.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 32.8ms
# Speed: 0.0ms preprocess, 32.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 41.9ms
# Speed: 0.0ms preprocess, 41.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 34.4ms
# Speed: 0.6ms preprocess, 34.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 31.9ms
# Speed: 1.0ms preprocess, 31.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 45.5ms
# Speed: 1.5ms preprocess, 45.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 37.2ms
# Speed: 0.0ms preprocess, 37.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 37.9ms
# Speed: 0.0ms preprocess, 37.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 36.0ms
# Speed: 0.0ms preprocess, 36.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 33.3ms
# Speed: 0.0ms preprocess, 33.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 38.6ms
# Speed: 0.0ms preprocess, 38.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 37.7ms
# Speed: 0.0ms preprocess, 37.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 32.5ms
# Speed: 0.0ms preprocess, 32.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 34.9ms
# Speed: 1.0ms preprocess, 34.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 38.2ms
# Speed: 0.0ms preprocess, 38.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 40.6ms
# Speed: 0.0ms preprocess, 40.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 43.1ms
# Speed: 1.5ms preprocess, 43.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 47.0ms
# Speed: 1.0ms preprocess, 47.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 4 cars, 40.4ms
# Speed: 1.3ms preprocess, 40.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 3 cars, 35.4ms
# Speed: 1.0ms preprocess, 35.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 36.4ms
# Speed: 1.0ms preprocess, 36.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 44.0ms
# Speed: 1.0ms preprocess, 44.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 41.5ms
# Speed: 0.5ms preprocess, 41.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 33.2ms
# Speed: 0.0ms preprocess, 33.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 36.1ms
# Speed: 0.0ms preprocess, 36.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 3 cars, 32.7ms
# Speed: 2.0ms preprocess, 32.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 3 cars, 42.6ms
# Speed: 0.0ms preprocess, 42.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 3 cars, 34.9ms
# Speed: 1.0ms preprocess, 34.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 3 cars, 37.1ms
# Speed: 0.0ms preprocess, 37.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 4 cars, 37.8ms
# Speed: 0.0ms preprocess, 37.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 4 cars, 37.0ms
# Speed: 1.6ms preprocess, 37.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 4 cars, 51.7ms
# Speed: 0.7ms preprocess, 51.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 4 cars, 45.7ms
# Speed: 1.0ms preprocess, 45.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 4 cars, 35.2ms
# Speed: 0.0ms preprocess, 35.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 4 cars, 44.8ms
# Speed: 0.0ms preprocess, 44.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 4 cars, 40.0ms
# Speed: 0.0ms preprocess, 40.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 4 cars, 33.5ms
# Speed: 1.0ms preprocess, 33.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 4 cars, 37.2ms
# Speed: 0.0ms preprocess, 37.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 4 cars, 41.4ms
# Speed: 1.5ms preprocess, 41.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 4 cars, 34.6ms
# Speed: 0.0ms preprocess, 34.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 4 cars, 36.8ms
# Speed: 0.0ms preprocess, 36.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 4 cars, 33.7ms
# Speed: 0.0ms preprocess, 33.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 4 cars, 35.8ms
# Speed: 0.0ms preprocess, 35.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 4 cars, 31.2ms
# Speed: 1.0ms preprocess, 31.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 4 cars, 37.7ms
# Speed: 1.0ms preprocess, 37.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 4 cars, 46.5ms
# Speed: 1.1ms preprocess, 46.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 4 cars, 37.5ms
# Speed: 1.0ms preprocess, 37.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 4 cars, 54.0ms
# Speed: 0.0ms preprocess, 54.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 3 cars, 32.5ms
# Speed: 1.0ms preprocess, 32.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 3 cars, 34.9ms
# Speed: 0.0ms preprocess, 34.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 3 cars, 34.5ms
# Speed: 0.8ms preprocess, 34.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 3 cars, 47.0ms
# Speed: 0.0ms preprocess, 47.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 3 cars, 37.3ms
# Speed: 0.0ms preprocess, 37.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 3 cars, 39.0ms
# Speed: 1.0ms preprocess, 39.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 3 cars, 34.5ms
# Speed: 0.0ms preprocess, 34.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 2 cars, 36.1ms
# Speed: 0.0ms preprocess, 36.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 2 cars, 34.4ms
# Speed: 0.0ms preprocess, 34.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 2 cars, 39.9ms
# Speed: 1.0ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 2 cars, 38.7ms
# Speed: 0.0ms preprocess, 38.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 2 cars, 35.1ms
# Speed: 1.6ms preprocess, 35.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 2 cars, 32.9ms
# Speed: 2.0ms preprocess, 32.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 2 cars, 40.4ms
# Speed: 0.5ms preprocess, 40.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 2 cars, 48.7ms
# Speed: 0.0ms preprocess, 48.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 42.9ms
# Speed: 0.0ms preprocess, 42.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 36.6ms
# Speed: 1.5ms preprocess, 36.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 37.6ms
# Speed: 0.0ms preprocess, 37.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 44.9ms
# Speed: 1.1ms preprocess, 44.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 43.0ms
# Speed: 0.7ms preprocess, 43.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 38.5ms
# Speed: 0.0ms preprocess, 38.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 36.8ms
# Speed: 1.0ms preprocess, 36.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 37.3ms
# Speed: 2.7ms preprocess, 37.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 1 car, 36.9ms
# Speed: 0.0ms preprocess, 36.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 1 car, 36.4ms
# Speed: 1.0ms preprocess, 36.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 1 car, 40.7ms
# Speed: 0.0ms preprocess, 40.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 1 car, 37.8ms
# Speed: 0.0ms preprocess, 37.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 1 car, 41.1ms
# Speed: 0.0ms preprocess, 41.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 1 car, 37.1ms
# Speed: 4.6ms preprocess, 37.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 1 car, 38.9ms
# Speed: 0.0ms preprocess, 38.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 1 car, 40.2ms
# Speed: 1.0ms preprocess, 40.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 1 car, 52.8ms
# Speed: 0.0ms preprocess, 52.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 1 car, 39.9ms
# Speed: 0.0ms preprocess, 39.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 1 car, 36.6ms
# Speed: 0.0ms preprocess, 36.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 1 car, 35.9ms
# Speed: 0.0ms preprocess, 35.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 1 car, 35.6ms
# Speed: 0.0ms preprocess, 35.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 1 car, 36.9ms
# Speed: 0.0ms preprocess, 36.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 1 car, 41.8ms
# Speed: 0.0ms preprocess, 41.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 1 car, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 54.8ms
# Speed: 0.0ms preprocess, 54.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 43.0ms
# Speed: 1.0ms preprocess, 43.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 42.2ms
# Speed: 0.0ms preprocess, 42.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 37.5ms
# Speed: 2.5ms preprocess, 37.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 37.6ms
# Speed: 0.0ms preprocess, 37.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 39.5ms
# Speed: 0.0ms preprocess, 39.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 41.1ms
# Speed: 0.0ms preprocess, 41.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 37.0ms
# Speed: 0.0ms preprocess, 37.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 36.6ms
# Speed: 0.0ms preprocess, 36.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 36.9ms
# Speed: 0.0ms preprocess, 36.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 34.9ms
# Speed: 5.6ms preprocess, 34.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 41.5ms
# Speed: 0.0ms preprocess, 41.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 1 car, 39.4ms
# Speed: 0.0ms preprocess, 39.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 1 car, 37.7ms
# Speed: 0.0ms preprocess, 37.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 1 car, 40.9ms
# Speed: 1.1ms preprocess, 40.9ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 1 car, 39.6ms
# Speed: 0.0ms preprocess, 39.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 1 car, 43.8ms
# Speed: 6.3ms preprocess, 43.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 1 car, 38.5ms
# Speed: 0.0ms preprocess, 38.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 1 car, 34.2ms
# Speed: 0.6ms preprocess, 34.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 1 car, 40.5ms
# Speed: 0.0ms preprocess, 40.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 1 car, 47.4ms
# Speed: 0.0ms preprocess, 47.4ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 1 car, 44.2ms
# Speed: 0.0ms preprocess, 44.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 1 car, 38.0ms
# Speed: 0.0ms preprocess, 38.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 1 car, 37.7ms
# Speed: 0.0ms preprocess, 37.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 1 car, 31.9ms
# Speed: 1.0ms preprocess, 31.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 1 car, 43.8ms
# Speed: 0.0ms preprocess, 43.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 1 car, 46.3ms
# Speed: 0.0ms preprocess, 46.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 1 car, 52.1ms
# Speed: 0.0ms preprocess, 52.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 motorbikes, 1 car, 54.0ms
# Speed: 0.0ms preprocess, 54.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 motorbikes, 1 car, 41.4ms
# Speed: 1.0ms preprocess, 41.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 motorbikes, 2 cars, 44.7ms
# Speed: 0.0ms preprocess, 44.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 motorbikes, 2 cars, 41.8ms
# Speed: 0.8ms preprocess, 41.8ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 motorbikes, 3 cars, 35.7ms
# Speed: 0.0ms preprocess, 35.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 2 cars, 33.4ms
# Speed: 0.0ms preprocess, 33.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 2 cars, 39.4ms
# Speed: 1.0ms preprocess, 39.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 2 cars, 45.4ms
# Speed: 0.5ms preprocess, 45.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 2 cars, 37.8ms
# Speed: 0.0ms preprocess, 37.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 2 cars, 33.1ms
# Speed: 1.0ms preprocess, 33.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 2 cars, 47.7ms
# Speed: 1.1ms preprocess, 47.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 2 cars, 36.3ms
# Speed: 0.0ms preprocess, 36.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 2 cars, 50.7ms
# Speed: 0.0ms preprocess, 50.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 2 cars, 34.7ms
# Speed: 0.0ms preprocess, 34.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 2 cars, 35.2ms
# Speed: 2.5ms preprocess, 35.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 3 cars, 35.2ms
# Speed: 0.0ms preprocess, 35.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 3 cars, 38.3ms
# Speed: 0.0ms preprocess, 38.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 3 cars, 35.7ms
# Speed: 0.0ms preprocess, 35.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 3 cars, 35.3ms
# Speed: 0.0ms preprocess, 35.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 3 cars, 37.5ms
# Speed: 0.0ms preprocess, 37.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 3 cars, 34.0ms
# Speed: 1.5ms preprocess, 34.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 3 cars, 42.7ms
# Speed: 1.3ms preprocess, 42.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 47.1ms
# Speed: 0.0ms preprocess, 47.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 33.7ms
# Speed: 1.6ms preprocess, 33.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 32.9ms
# Speed: 1.5ms preprocess, 32.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 35.9ms
# Speed: 1.0ms preprocess, 35.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 38.0ms
# Speed: 0.0ms preprocess, 38.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 37.9ms
# Speed: 0.0ms preprocess, 37.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 48.1ms
# Speed: 0.0ms preprocess, 48.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 48.2ms
# Speed: 1.0ms preprocess, 48.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 38.9ms
# Speed: 0.0ms preprocess, 38.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 56.8ms
# Speed: 0.0ms preprocess, 56.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 45.5ms
# Speed: 0.0ms preprocess, 45.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 41.8ms
# Speed: 1.0ms preprocess, 41.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 36.6ms
# Speed: 0.9ms preprocess, 36.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 44.6ms
# Speed: 1.0ms preprocess, 44.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 3 cars, 50.9ms
# Speed: 0.0ms preprocess, 50.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 2 cars, 44.0ms
# Speed: 1.0ms preprocess, 44.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 2 cars, 44.5ms
# Speed: 0.0ms preprocess, 44.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 2 cars, 45.3ms
# Speed: 0.0ms preprocess, 45.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 2 cars, 35.2ms
# Speed: 1.5ms preprocess, 35.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 2 cars, 35.7ms
# Speed: 0.0ms preprocess, 35.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 2 cars, 36.4ms
# Speed: 0.0ms preprocess, 36.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 42.1ms
# Speed: 0.0ms preprocess, 42.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 39.3ms
# Speed: 0.0ms preprocess, 39.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 38.2ms
# Speed: 1.5ms preprocess, 38.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 43.1ms
# Speed: 0.0ms preprocess, 43.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 2 cars, 54.1ms
# Speed: 1.0ms preprocess, 54.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 2 cars, 52.5ms
# Speed: 0.0ms preprocess, 52.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 2 cars, 48.0ms
# Speed: 0.0ms preprocess, 48.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 1 car, 57.7ms
# Speed: 0.0ms preprocess, 57.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 1 car, 57.7ms
# Speed: 0.0ms preprocess, 57.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 1 car, 57.1ms
# Speed: 0.0ms preprocess, 57.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 1 car, 57.0ms
# Speed: 0.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 1 car, 49.3ms
# Speed: 0.0ms preprocess, 49.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 1 car, 36.4ms
# Speed: 1.0ms preprocess, 36.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 2 cars, 50.2ms
# Speed: 1.5ms preprocess, 50.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 2 cars, 53.2ms
# Speed: 0.6ms preprocess, 53.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 1 car, 53.0ms
# Speed: 1.1ms preprocess, 53.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 1 car, 53.3ms
# Speed: 0.0ms preprocess, 53.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 1 car, 53.5ms
# Speed: 0.0ms preprocess, 53.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 1 car, 53.4ms
# Speed: 1.1ms preprocess, 53.4ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 2 cars, 49.3ms
# Speed: 0.5ms preprocess, 49.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 2 cars, 50.1ms
# Speed: 1.0ms preprocess, 50.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 2 cars, 42.2ms
# Speed: 1.3ms preprocess, 42.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 2 cars, 52.7ms
# Speed: 1.1ms preprocess, 52.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 2 cars, 56.2ms
# Speed: 1.0ms preprocess, 56.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 2 cars, 41.7ms
# Speed: 0.8ms preprocess, 41.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 2 cars, 34.1ms
# Speed: 0.0ms preprocess, 34.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 2 cars, 58.3ms
# Speed: 1.1ms preprocess, 58.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 2 cars, 48.3ms
# Speed: 0.7ms preprocess, 48.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 2 cars, 57.4ms
# Speed: 0.0ms preprocess, 57.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 2 cars, 52.4ms
# Speed: 0.0ms preprocess, 52.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 2 cars, 39.5ms
# Speed: 1.2ms preprocess, 39.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 2 cars, 39.8ms
# Speed: 0.6ms preprocess, 39.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 2 cars, 50.2ms
# Speed: 2.0ms preprocess, 50.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 2 cars, 47.9ms
# Speed: 1.0ms preprocess, 47.9ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 2 cars, 52.2ms
# Speed: 1.0ms preprocess, 52.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 2 cars, 50.1ms
# Speed: 0.0ms preprocess, 50.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 2 cars, 42.9ms
# Speed: 0.0ms preprocess, 42.9ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 2 cars, 35.4ms
# Speed: 0.0ms preprocess, 35.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 2 cars, 35.7ms
# Speed: 1.0ms preprocess, 35.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 2 cars, 36.1ms
# Speed: 0.0ms preprocess, 36.1ms inference, 8.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 2 cars, 56.2ms
# Speed: 1.5ms preprocess, 56.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 2 cars, 53.7ms
# Speed: 1.1ms preprocess, 53.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 2 cars, 46.3ms
# Speed: 1.2ms preprocess, 46.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 2 cars, 59.8ms
# Speed: 0.0ms preprocess, 59.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 61.1ms
# Speed: 0.5ms preprocess, 61.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 2 cars, 53.3ms
# Speed: 0.0ms preprocess, 53.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 2 cars, 58.7ms
# Speed: 0.0ms preprocess, 58.7ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 2 cars, 44.8ms
# Speed: 0.6ms preprocess, 44.8ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 2 cars, 51.4ms
# Speed: 2.0ms preprocess, 51.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 2 cars, 51.2ms
# Speed: 1.0ms preprocess, 51.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 2 cars, 46.5ms
# Speed: 0.0ms preprocess, 46.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 2 cars, 45.4ms
# Speed: 0.0ms preprocess, 45.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 2 cars, 53.0ms
# Speed: 0.0ms preprocess, 53.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 1 car, 53.6ms
# Speed: 0.0ms preprocess, 53.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 1 car, 48.8ms
# Speed: 0.0ms preprocess, 48.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 1 car, 29.7ms
# Speed: 1.1ms preprocess, 29.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 1 car, 46.6ms
# Speed: 2.6ms preprocess, 46.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 1 car, 55.8ms
# Speed: 0.0ms preprocess, 55.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 1 car, 53.6ms
# Speed: 0.0ms preprocess, 53.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 1 car, 53.4ms
# Speed: 1.5ms preprocess, 53.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 1 car, 42.2ms
# Speed: 0.0ms preprocess, 42.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 1 car, 35.0ms
# Speed: 0.7ms preprocess, 35.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 1 car, 59.7ms
# Speed: 0.0ms preprocess, 59.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 39.2ms
# Speed: 0.6ms preprocess, 39.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 58.2ms
# Speed: 6.5ms preprocess, 58.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 car, 56.6ms
# Speed: 0.0ms preprocess, 56.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 52.5ms
# Speed: 0.5ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 56.0ms
# Speed: 1.0ms preprocess, 56.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 54.9ms
# Speed: 4.8ms preprocess, 54.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 36.0ms
# Speed: 0.5ms preprocess, 36.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 40.2ms
# Speed: 2.0ms preprocess, 40.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 38.1ms
# Speed: 0.0ms preprocess, 38.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 3 cars, 33.8ms
# Speed: 1.5ms preprocess, 33.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 3 cars, 42.0ms
# Speed: 0.0ms preprocess, 42.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 3 cars, 46.8ms
# Speed: 1.1ms preprocess, 46.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 3 cars, 33.7ms
# Speed: 1.0ms preprocess, 33.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 3 cars, 40.6ms
# Speed: 0.0ms preprocess, 40.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 3 cars, 36.6ms
# Speed: 0.0ms preprocess, 36.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 3 cars, 39.9ms
# Speed: 0.0ms preprocess, 39.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 3 cars, 44.7ms
# Speed: 0.0ms preprocess, 44.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 3 cars, 51.6ms
# Speed: 0.7ms preprocess, 51.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 3 cars, 39.5ms
# Speed: 1.0ms preprocess, 39.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 3 cars, 33.7ms
# Speed: 0.0ms preprocess, 33.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 3 cars, 43.0ms
# Speed: 1.0ms preprocess, 43.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 4 cars, 36.8ms
# Speed: 1.5ms preprocess, 36.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 4 cars, 49.6ms
# Speed: 1.3ms preprocess, 49.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 4 cars, 38.7ms
# Speed: 1.9ms preprocess, 38.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 4 cars, 36.0ms
# Speed: 0.6ms preprocess, 36.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 4 cars, 31.9ms
# Speed: 1.0ms preprocess, 31.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 3 cars, 33.4ms
# Speed: 1.0ms preprocess, 33.4ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 3 cars, 34.6ms
# Speed: 0.0ms preprocess, 34.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 3 cars, 35.1ms
# Speed: 0.0ms preprocess, 35.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 3 cars, 41.3ms
# Speed: 0.0ms preprocess, 41.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 3 cars, 47.4ms
# Speed: 0.8ms preprocess, 47.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 3 cars, 35.0ms
# Speed: 0.0ms preprocess, 35.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 3 cars, 38.3ms
# Speed: 1.5ms preprocess, 38.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 3 cars, 44.2ms
# Speed: 0.0ms preprocess, 44.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 3 cars, 44.3ms
# Speed: 1.3ms preprocess, 44.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 3 cars, 55.0ms
# Speed: 0.0ms preprocess, 55.0ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 3 cars, 42.1ms
# Speed: 0.8ms preprocess, 42.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 3 cars, 44.0ms
# Speed: 0.0ms preprocess, 44.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 motorbike, 3 cars, 35.8ms
# Speed: 0.0ms preprocess, 35.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 3 cars, 41.8ms
# Speed: 1.0ms preprocess, 41.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 3 cars, 51.0ms
# Speed: 0.0ms preprocess, 51.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 motorbikes, 2 cars, 43.1ms
# Speed: 1.7ms preprocess, 43.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 2 cars, 49.1ms
# Speed: 0.0ms preprocess, 49.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 2 cars, 50.0ms
# Speed: 5.0ms preprocess, 50.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 2 cars, 47.9ms
# Speed: 0.0ms preprocess, 47.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 35.4ms
# Speed: 0.7ms preprocess, 35.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 32.4ms
# Speed: 4.6ms preprocess, 32.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 38.7ms
# Speed: 1.0ms preprocess, 38.7ms inference, 3.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 36.2ms
# Speed: 0.0ms preprocess, 36.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 35.3ms
# Speed: 1.7ms preprocess, 35.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 34.7ms
# Speed: 0.0ms preprocess, 34.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 40.0ms
# Speed: 0.8ms preprocess, 40.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 39.4ms
# Speed: 0.9ms preprocess, 39.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 50.1ms
# Speed: 4.1ms preprocess, 50.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 33.7ms
# Speed: 0.0ms preprocess, 33.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 46.0ms
# Speed: 0.0ms preprocess, 46.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 56.2ms
# Speed: 0.0ms preprocess, 56.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 45.7ms
# Speed: 1.0ms preprocess, 45.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 2 cars, 54.1ms
# Speed: 2.0ms preprocess, 54.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 2 cars, 40.1ms
# Speed: 1.5ms preprocess, 40.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 39.3ms
# Speed: 0.0ms preprocess, 39.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 33.5ms
# Speed: 1.0ms preprocess, 33.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 34.2ms
# Speed: 1.0ms preprocess, 34.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 35.9ms
# Speed: 0.0ms preprocess, 35.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 37.8ms
# Speed: 0.0ms preprocess, 37.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 36.8ms
# Speed: 0.0ms preprocess, 36.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 38.7ms
# Speed: 0.0ms preprocess, 38.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 37.8ms
# Speed: 0.0ms preprocess, 37.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 39.3ms
# Speed: 0.0ms preprocess, 39.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 5 cars, 38.1ms
# Speed: 2.0ms preprocess, 38.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 5 cars, 40.5ms
# Speed: 1.0ms preprocess, 40.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 4 cars, 40.9ms
# Speed: 0.0ms preprocess, 40.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 5 cars, 49.8ms
# Speed: 3.3ms preprocess, 49.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 5 cars, 40.9ms
# Speed: 0.6ms preprocess, 40.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 5 cars, 46.1ms
# Speed: 0.0ms preprocess, 46.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 5 cars, 45.9ms
# Speed: 0.5ms preprocess, 45.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 5 cars, 43.5ms
# Speed: 1.0ms preprocess, 43.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 5 cars, 43.2ms
# Speed: 1.4ms preprocess, 43.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 5 cars, 30.1ms
# Speed: 5.5ms preprocess, 30.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 5 cars, 34.2ms
# Speed: 1.0ms preprocess, 34.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 5 cars, 35.3ms
# Speed: 1.0ms preprocess, 35.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 5 cars, 37.9ms
# Speed: 0.0ms preprocess, 37.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 5 cars, 34.7ms
# Speed: 0.0ms preprocess, 34.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 5 cars, 36.6ms
# Speed: 0.0ms preprocess, 36.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 35.9ms
# Speed: 0.0ms preprocess, 35.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 40.9ms
# Speed: 0.0ms preprocess, 40.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 35.0ms
# Speed: 3.1ms preprocess, 35.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 34.1ms
# Speed: 1.0ms preprocess, 34.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 48.1ms
# Speed: 0.5ms preprocess, 48.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 40.0ms
# Speed: 0.0ms preprocess, 40.0ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 6 cars, 53.0ms
# Speed: 0.5ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 5 cars, 43.8ms
# Speed: 0.5ms preprocess, 43.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 5 cars, 41.1ms
# Speed: 0.0ms preprocess, 41.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 4 cars, 35.5ms
# Speed: 4.5ms preprocess, 35.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 4 cars, 39.0ms
# Speed: 0.0ms preprocess, 39.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 3 cars, 36.1ms
# Speed: 1.0ms preprocess, 36.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 3 cars, 33.3ms
# Speed: 1.0ms preprocess, 33.3ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 3 cars, 38.6ms
# Speed: 0.0ms preprocess, 38.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# ...
#
# 0: 320x640 4 motorbikes, 3 cars, 42.9ms
# Speed: 0.7ms preprocess, 42.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 48.9ms
# Speed: 1.0ms preprocess, 48.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 38.9ms
# Speed: 0.0ms preprocess, 38.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 33.5ms
# Speed: 0.0ms preprocess, 33.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 34.7ms
# Speed: 3.2ms preprocess, 34.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 52.9ms
# Speed: 0.0ms preprocess, 52.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 4 cars, 42.8ms
# Speed: 0.0ms preprocess, 42.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 49.6ms
# Speed: 1.0ms preprocess, 49.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 4 cars, 45.8ms
# Speed: 0.0ms preprocess, 45.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 5 cars, 51.7ms
# Speed: 4.7ms preprocess, 51.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 5 cars, 41.2ms
# Speed: 0.5ms preprocess, 41.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 5 cars, 39.0ms
# Speed: 1.0ms preprocess, 39.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 5 cars, 46.1ms
# Speed: 0.0ms preprocess, 46.1ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 5 cars, 46.6ms
# Speed: 0.0ms preprocess, 46.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 5 cars, 34.9ms
# Speed: 2.0ms preprocess, 34.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 5 cars, 48.2ms
# Speed: 0.0ms preprocess, 48.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 5 cars, 43.2ms
# Speed: 0.0ms preprocess, 43.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 5 cars, 51.7ms
# Speed: 1.0ms preprocess, 51.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 5 cars, 45.5ms
# Speed: 0.0ms preprocess, 45.5ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 motorbikes, 5 cars, 42.7ms
# Speed: 0.0ms preprocess, 42.7ms inference, 3.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 5 cars, 43.6ms
# Speed: 0.0ms preprocess, 43.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 5 cars, 52.7ms
# Speed: 2.5ms preprocess, 52.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 5 cars, 52.3ms
# Speed: 1.0ms preprocess, 52.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 5 cars, 42.5ms
# Speed: 1.1ms preprocess, 42.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 5 cars, 36.5ms
# Speed: 0.0ms preprocess, 36.5ms inference, 8.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 4 cars, 45.3ms
# Speed: 0.0ms preprocess, 45.3ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 4 cars, 46.4ms
# Speed: 0.5ms preprocess, 46.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 4 cars, 52.2ms
# Speed: 0.0ms preprocess, 52.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 4 cars, 44.3ms
# Speed: 0.0ms preprocess, 44.3ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 4 cars, 51.5ms
# Speed: 0.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 4 cars, 45.2ms
# Speed: 0.0ms preprocess, 45.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 4 cars, 45.1ms
# Speed: 0.0ms preprocess, 45.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 4 cars, 50.0ms
# Speed: 0.0ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 4 cars, 43.1ms
# Speed: 1.0ms preprocess, 43.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 4 cars, 46.3ms
# Speed: 1.0ms preprocess, 46.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 4 cars, 52.0ms
# Speed: 0.0ms preprocess, 52.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 4 cars, 49.8ms
# Speed: 1.5ms preprocess, 49.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 4 cars, 59.6ms
# Speed: 1.0ms preprocess, 59.6ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 5 cars, 50.4ms
# Speed: 1.0ms preprocess, 50.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 5 cars, 55.4ms
# Speed: 1.0ms preprocess, 55.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 5 cars, 43.8ms
# Speed: 1.3ms preprocess, 43.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 5 cars, 57.4ms
# Speed: 0.5ms preprocess, 57.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 motorbikes, 5 cars, 43.5ms
# Speed: 1.0ms preprocess, 43.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 5 cars, 49.5ms
# Speed: 0.0ms preprocess, 49.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 5 cars, 41.1ms
# Speed: 0.0ms preprocess, 41.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 7 cars, 56.5ms
# Speed: 1.5ms preprocess, 56.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 6 cars, 45.7ms
# Speed: 1.5ms preprocess, 45.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 5 cars, 41.4ms
# Speed: 0.0ms preprocess, 41.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 5 cars, 61.0ms
# Speed: 0.0ms preprocess, 61.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 5 cars, 46.4ms
# Speed: 0.5ms preprocess, 46.4ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 5 cars, 43.3ms
# Speed: 1.0ms preprocess, 43.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 5 cars, 44.8ms
# Speed: 1.0ms preprocess, 44.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 5 cars, 55.3ms
# Speed: 1.5ms preprocess, 55.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 5 cars, 52.9ms
# Speed: 0.0ms preprocess, 52.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 5 cars, 54.0ms
# Speed: 0.0ms preprocess, 54.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 5 cars, 50.1ms
# Speed: 0.0ms preprocess, 50.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 5 cars, 44.7ms
# Speed: 1.0ms preprocess, 44.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 motorbikes, 5 cars, 33.2ms
# Speed: 0.0ms preprocess, 33.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 5 cars, 39.4ms
# Speed: 0.0ms preprocess, 39.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 5 cars, 49.2ms
# Speed: 1.0ms preprocess, 49.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 5 cars, 42.0ms
# Speed: 0.0ms preprocess, 42.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 5 cars, 53.9ms
# Speed: 1.0ms preprocess, 53.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 40.6ms
# Speed: 0.0ms preprocess, 40.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 45.3ms
# Speed: 1.5ms preprocess, 45.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 51.4ms
# Speed: 1.0ms preprocess, 51.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 43.9ms
# Speed: 1.0ms preprocess, 43.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 45.2ms
# Speed: 1.0ms preprocess, 45.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 52.4ms
# Speed: 0.5ms preprocess, 52.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 44.4ms
# Speed: 0.0ms preprocess, 44.4ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 4 cars, 49.4ms
# Speed: 1.3ms preprocess, 49.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 42.3ms
# Speed: 1.0ms preprocess, 42.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 39.7ms
# Speed: 0.0ms preprocess, 39.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 43.7ms
# Speed: 5.2ms preprocess, 43.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 59.3ms
# Speed: 4.4ms preprocess, 59.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 46.8ms
# Speed: 1.6ms preprocess, 46.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 54.1ms
# Speed: 1.0ms preprocess, 54.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 43.7ms
# Speed: 0.0ms preprocess, 43.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 44.1ms
# Speed: 0.0ms preprocess, 44.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 44.7ms
# Speed: 1.5ms preprocess, 44.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 4 cars, 46.0ms
# Speed: 0.0ms preprocess, 46.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 50.7ms
# Speed: 0.5ms preprocess, 50.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 4 cars, 44.3ms
# Speed: 2.0ms preprocess, 44.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 45.8ms
# Speed: 0.0ms preprocess, 45.8ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 54.6ms
# Speed: 0.5ms preprocess, 54.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 40.0ms
# Speed: 1.5ms preprocess, 40.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 36.9ms
# Speed: 1.0ms preprocess, 36.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 50.8ms
# Speed: 1.0ms preprocess, 50.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 39.4ms
# Speed: 2.0ms preprocess, 39.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 48.1ms
# Speed: 1.0ms preprocess, 48.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 motorbikes, 3 cars, 42.0ms
# Speed: 0.0ms preprocess, 42.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 39.9ms
# Speed: 0.0ms preprocess, 39.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 36.2ms
# Speed: 0.0ms preprocess, 36.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 50.2ms
# Speed: 1.5ms preprocess, 50.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 42.0ms
# Speed: 0.0ms preprocess, 42.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 41.9ms
# Speed: 1.0ms preprocess, 41.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 41.2ms
# Speed: 1.0ms preprocess, 41.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 51.7ms
# Speed: 1.0ms preprocess, 51.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 48.9ms
# Speed: 0.0ms preprocess, 48.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 motorbikes, 3 cars, 46.0ms
# Speed: 0.0ms preprocess, 46.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 60.5ms
# Speed: 0.0ms preprocess, 60.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 3 cars, 41.1ms
# Speed: 1.0ms preprocess, 41.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 39.0ms
# Speed: 1.0ms preprocess, 39.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 48.9ms
# Speed: 0.0ms preprocess, 48.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 35.6ms
# Speed: 0.0ms preprocess, 35.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 37.6ms
# Speed: 0.0ms preprocess, 37.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 44.4ms
# Speed: 0.0ms preprocess, 44.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 44.0ms
# Speed: 0.0ms preprocess, 44.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 42.7ms
# Speed: 1.0ms preprocess, 42.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 41.4ms
# Speed: 0.0ms preprocess, 41.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 42.6ms
# Speed: 0.5ms preprocess, 42.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 38.7ms
# Speed: 0.0ms preprocess, 38.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 36.1ms
# Speed: 0.0ms preprocess, 36.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 72.4ms
# Speed: 1.0ms preprocess, 72.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 motorbikes, 4 cars, 53.8ms
# Speed: 1.6ms preprocess, 53.8ms inference, 6.1ms postprocess per image at shape (1, 3, 320, 640)
# Video frame is empty or video processing has been successfully completed.

# %%
cv.waitKey(0)
cap.release()   # Release the capture
video_writer.release()
cv.destroyAllWindows()

# %%
counter.classwise_counts
# Out:
# {'motorbike': {'IN': 120, 'OUT': 0},
#  'car': {'IN': 50, 'OUT': 0},
#  'person': {'IN': 0, 'OUT': 0}}

# %%
# cv.imshow("img", im0_original)
# cv.waitKey(0)

# %% [markdown]
# Camlytics Benchmark

# %%
# ### manual
# bicycle		: 5
# car		    : 16
# motorbike	: 68
# bus		    : 1
# person		: 4

# ### yolo11n_crop_skip1
# bicycle		: 5
# car		    : 16
# motorbike	: 65
# bus		    : 1
# person		: 4

# ### camlytics
# exit		: 76
# ---
# pedestrian	: 70
# unknown		: 1
# vehicle		: 5

# enter		: 49
# ---
# pedestrian	: 31
# unknown		: 5
# vehicle		: 13
